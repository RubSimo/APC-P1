# %%
# afegim llibreries necessaries
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
# %matplotlib notebook
from matplotlib import pyplot as plt
import scipy.stats
import seaborn as sns

# visualitzarem només 3 decimals per mostra
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# llegim les dades del csv
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

# carreguem dataset 
dataset = load_dataset('forestfires.csv')
data = dataset.values

# %%
print("Visualitzem les primeres 5 mostres de la BBDD:")
dataset.head()
# Out:
# Visualitzem les primeres 5 mostres de la BBDD:
#    X  Y month  day   FFMC    DMC      DC   ISI   temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.200 26.200  94.300 5.100  8.200  51 6.700 0.000 0.000
# 1  7  4   oct  tue 90.600 35.400 669.100 6.700 18.000  33 0.900 0.000 0.000
# 2  7  4   oct  sat 90.600 43.700 686.900 6.700 14.600  33 1.300 0.000 0.000
# 3  8  6   mar  fri 91.700 33.300  77.500 9.000  8.300  97 4.000 0.200 0.000
# 4  8  6   mar  sun 89.300 51.300 102.200 9.600 11.400  99 1.800 0.000 0.000

# %%
# comprovar tipus de dades
dataset.dtypes
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %%
# convertir dades a tipus numèric
#dataset = dataset.apply(pd.to_numeric, errors= 'coerce')
#dataset.head()

# %%
# comptem els valors no existents
noExist = dataset.isnull().sum()
print(noExist)
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
i = 0
while i < 517:
    if dataset['month'][i] == 'jan':
        dataset['month'][i] = 1
    elif dataset['month'][i] == 'feb':
        dataset['month'][i] = 2
    elif dataset['month'][i] == 'mar':
        dataset['month'][i] = 3
    elif dataset['month'][i] == 'apr':
        dataset['month'][i] = 4
    elif dataset['month'][i] == 'may':
        dataset['month'][i] = 5
    elif dataset['month'][i] == 'jun':
        dataset['month'][i] = 6
    elif dataset['month'][i] == 'jul':
        dataset['month'][i] = 7
    elif dataset['month'][i] == 'aug':
        dataset['month'][i] = 8
    elif dataset['month'][i] == 'sep':
        dataset['month'][i] = 9
    elif dataset['month'][i] == 'oct':
        dataset['month'][i] = 10
    elif dataset['month'][i] == 'nov':
        dataset['month'][i] = 11
    elif dataset['month'][i] == 'dec':
        dataset['month'][i] = 12
    i += 1

dataset.head()
# Out:
# /tmp/ipykernel_9685/1819461582.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 3
# /tmp/ipykernel_9685/1819461582.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 10
# /tmp/ipykernel_9685/1819461582.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 8
# /tmp/ipykernel_9685/1819461582.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 9
# /tmp/ipykernel_9685/1819461582.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 4
# /tmp/ipykernel_9685/1819461582.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 6
# /tmp/ipykernel_9685/1819461582.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 7
# /tmp/ipykernel_9685/1819461582.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 2
# /tmp/ipykernel_9685/1819461582.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 1
# /tmp/ipykernel_9685/1819461582.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 12
# /tmp/ipykernel_9685/1819461582.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 5
# /tmp/ipykernel_9685/1819461582.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['month'][i] = 11
#    X  Y month  day   FFMC    DMC      DC   ISI   temp  RH  wind  rain  area
# 0  7  5     3  fri 86.200 26.200  94.300 5.100  8.200  51 6.700 0.000 0.000
# 1  7  4    10  tue 90.600 35.400 669.100 6.700 18.000  33 0.900 0.000 0.000
# 2  7  4    10  sat 90.600 43.700 686.900 6.700 14.600  33 1.300 0.000 0.000
# 3  8  6     3  fri 91.700 33.300  77.500 9.000  8.300  97 4.000 0.200 0.000
# 4  8  6     3  sun 89.300 51.300 102.200 9.600 11.400  99 1.800 0.000 0.000

# %%
i = 0
while i < 517:
    if dataset['day'][i] == 'mon':
        dataset['day'][i] = 1
    elif dataset['day'][i] == 'tue':
        dataset['day'][i] = 2
    elif dataset['day'][i] == 'wed':
        dataset['day'][i] = 3
    elif dataset['day'][i] == 'thu':
        dataset['day'][i] = 4
    elif dataset['day'][i] == 'fri':
        dataset['day'][i] = 5
    elif dataset['day'][i] == 'sat':
        dataset['day'][i] = 6
    elif dataset['day'][i] == 'sun':
        dataset['day'][i] = 7
    i += 1
    
    
dataset["day"] = pd.to_numeric(dataset["day"])
dataset.head()
# Out:
# /tmp/ipykernel_9685/2035355516.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 5
# /tmp/ipykernel_9685/2035355516.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 2
# /tmp/ipykernel_9685/2035355516.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 6
# /tmp/ipykernel_9685/2035355516.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 7
# /tmp/ipykernel_9685/2035355516.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 1
# /tmp/ipykernel_9685/2035355516.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 3
# /tmp/ipykernel_9685/2035355516.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['day'][i] = 4
#    X  Y month  day   FFMC    DMC      DC   ISI   temp  RH  wind  rain  area
# 0  7  5     3    5 86.200 26.200  94.300 5.100  8.200  51 6.700 0.000 0.000
# 1  7  4    10    2 90.600 35.400 669.100 6.700 18.000  33 0.900 0.000 0.000
# 2  7  4    10    6 90.600 43.700 686.900 6.700 14.600  33 1.300 0.000 0.000
# 3  8  6     3    5 91.700 33.300  77.500 9.000  8.300  97 4.000 0.200 0.000
# 4  8  6     3    7 89.300 51.300 102.200 9.600 11.400  99 1.800 0.000 0.000

# %%
# canvi de object a int64 dels atributs any i dia per poder treballar comodament
dataset["day"] = pd.to_numeric(dataset["day"])
dataset["month"] = pd.to_numeric(dataset["month"])
dataset.dtypes
# Out:
# X          int64
# Y          int64
# month      int64
# day        int64
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %%
# anàlisis estadístic
dataset.describe()
# Out:
#             X       Y   month     day    FFMC     DMC      DC     ISI    temp  \
# count 517.000 517.000 517.000 517.000 517.000 517.000 517.000 517.000 517.000
# mean    4.669   4.300   7.476   4.259  90.645 110.872 547.940   9.022  18.889
# std     2.314   1.230   2.276   2.073   5.520  64.046 248.066   4.559   5.807
# min     1.000   2.000   1.000   1.000  18.700   1.100   7.900   0.000   2.200
# 25%     3.000   4.000   7.000   2.000  90.200  68.600 437.700   6.500  15.500
# 50%     4.000   4.000   8.000   5.000  91.600 108.300 664.200   8.400  19.300
# 75%     7.000   5.000   9.000   6.000  92.900 142.400 713.900  10.800  22.800
# max     9.000   9.000  12.000   7.000  96.200 291.300 860.600  56.100  33.300
#
#            RH    wind    rain     area
# count 517.000 517.000 517.000  517.000
# mean   44.288   4.018   0.022   12.847
# std    16.317   1.792   0.296   63.656
# min    15.000   0.400   0.000    0.000
# 25%    33.000   2.700   0.000    0.000
# 50%    42.000   4.000   0.000    0.520
# 75%    53.000   4.900   0.000    6.570
# max   100.000   9.400   6.400 1090.840

# %%
# mirem la correlació entre els atributs 
correlacio = dataset.corr()
plt.figure()
ax = sns.heatmap(correlacio, annot=True, linewidths=.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = dataset.values
days = data[:,3]

plt.figure()
plt.title("Histograma de l'atribut day")
plt.xlabel("dies")
plt.ylabel("numero de incendis")
hist = plt.hist(days,20)

#teniamos pensado quitar el atributo dias porque consideramos que no era importante teniendo ya los meses (pensabamos que cada dia tendria valores parecidos) pero cuando hemos hecho el histograma hemos visto que habia una gran diferencia entre los findes de semana y el resto de dias
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = dataset.values
month = data[:,2]

plt.figure()
plt.title("Histograma de l'atribut month")
plt.xlabel("mesos")
plt.ylabel("count")
hist = plt.hist(month,20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = dataset.values
temp = data[:, 8]
month = data[:,2]

plt.xlabel("mesos")
plt.ylabel("temp")

plt.plot(month,temp, 'ro')
plt.show()

# %%
def f_area(a):
    if a == 0.0:
        return 0
    else:
        return 1

dataset['damage'] = dataset['area'].apply(f_area)
dataset.head()
# Out:
#    X  Y  month  day   FFMC    DMC      DC   ISI   temp  RH  wind  rain  area  \
# 0  7  5      3    5 86.200 26.200  94.300 5.100  8.200  51 6.700 0.000 0.000
# 1  7  4     10    2 90.600 35.400 669.100 6.700 18.000  33 0.900 0.000 0.000
# 2  7  4     10    6 90.600 43.700 686.900 6.700 14.600  33 1.300 0.000 0.000
# 3  8  6      3    5 91.700 33.300  77.500 9.000  8.300  97 4.000 0.200 0.000
# 4  8  6      3    7 89.300 51.300 102.200 9.600 11.400  99 1.800 0.000 0.000
#
#    damage
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
sns.set_theme()
sns.scatterplot(data=dataset, x='month', y='temp', hue='damage')
# Out:
# <AxesSubplot:title={'center':"Histograma de l'atribut month"}, xlabel='mesos', ylabel='count'>
